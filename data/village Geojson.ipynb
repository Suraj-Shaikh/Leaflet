# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
# Load the shapefile
shapefile_path = 'C:/Users/HP/Desktop/del/village/mh_village_5129.shp'
gdf = gpd.read_file(shapefile_path)

# %%
# Convert to GeoJSON
geojson = gdf.to_json()

# %%
# Save to a file
with open('C:/Users/HP/Desktop/del/village/mh_village_5129_json.geojson', 'w') as f:
    f.write(geojson)

# %%
# Load the GeoJSON file
geojson_path = 'C:/Users/HP/Desktop/del/village/mh_village_5129_json.geojson'
gdf = gpd.read_file(geojson_path)

# %%
# Plot the GeoJSON data
gdf.plot()
# Out:
# <Axes: >
